# %% [markdown]
# # openai-community/gpt2
#
# **Model ID:** `openai-community/gpt2`
#
# **Pipeline:** text-generation
#
# **Description:** No description available
#
# [View on Hugging Face](https://huggingface.co/openai-community/gpt2)
#
# ---
#
# *This notebook was automatically generated by [Alacard](https://alacard.app).*

# %%
# Install required packages
# !pip install transformers huggingface_hub torch
# !pip install -U sentencepiece protobuf  # Often needed for Llama models

# %%
from transformers import pipeline
import torch

# Load openai-community/gpt2
try:
    pipe = pipeline('text-generation', model='openai-community/gpt2', device=0 if torch.cuda.is_available() else -1)
    print('✅ Model loaded successfully!')
    print(f'Model device: {"GPU" if torch.cuda.is_available() else "CPU"}')
except Exception as e:
    print(f'❌ Error loading model: {e}')
    print('You may need to authenticate with Hugging Face or use a different model.')

# %% [markdown]
# ## Model Information
#
# - **Name:** openai-community/gpt2
# - **Pipeline:** text-generation
# - **Downloads:** 11,232,781
# - **Likes:** 2,968
# - **Tags:** transformers, pytorch, tf, jax, tflite, rust, onnx, safetensors, gpt2, text-generation, exbert, en, doi:10.57967/hf/0039, license:mit, autotrain_compatible, text-generation-inference, endpoints_compatible, region:us
#
# ## Usage Tips
#
# - Make sure you have sufficient GPU memory for larger models
# - Some models may require Hugging Face authentication
# - Adjust generation parameters as needed for your use case

# %%
# Example from model README
>>> from transformers import pipeline, set_seed
>>> generator = pipeline('text-generation', model='gpt2')
>>> set_seed(42)
>>> generator("Hello, I'm a language model,", max_length=30, num_return_sequences=5)

[{'generated_text': "Hello, I'm a language model, a language for thinking, a language for expressing thoughts."},
 {'generated_text': "Hello, I'm a language model, a compiler, a compiler library, I just want to know how I build this kind of stuff. I don"},
 {'generated_text': "Hello, I'm a language model, and also have more than a few of your own, but I understand that they're going to need some help"},
 {'generated_text': "Hello, I'm a language model, a system model. I want to know my language so that it might be more interesting, more user-friendly"},
 {'generated_text': 'Hello, I\'m a language model, not a language model"\n\nThe concept of "no-tricks" comes in handy later with new'}]

# %%
# Text Generation Example
from transformers import pipeline

pipe = pipeline('text-generation', model='openai-community/gpt2')

prompt = "Once upon a time, in a land far, far away,"

# Generate text
output = pipe(
    prompt,
    max_length=100,
    num_return_sequences=1,
    temperature=0.7,
    do_sample=True
)

print(output[0]['generated_text'])

# %% [markdown]
# ## Next Steps
#
# ### Resources
# - [Model Card](https://huggingface.co/openai-community/gpt2)
# - [Hugging Face Documentation](https://huggingface.co/docs)
# - [Transformers Documentation](https://huggingface.co/docs/transformers)
#
# ### Ideas to Try
# - Fine-tune the model on your own data
# - Experiment with different generation parameters
# - Combine multiple models for complex tasks
# - Deploy the model as an API endpoint
#
# ---
#
# *Happy coding! 🚀*
